# %%
import pandas as pd

# %%
df = pd.read_csv("data/data.csv")

# %%
df.head()
# Out:
#               R_fighter       B_fighter          Referee        date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019-06-08
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...  R_win_by_KO/TKO  R_win_by_Submission  \
# ...

# %% [markdown]
# # Replace small num of missing vals
# ## R / B Height = 12 vals
# ## R / B Weight = 9 vals

# %%
df[df["R_Height_cms"].isnull()]
# Out:
#               R_fighter        B_fighter         Referee        date  \
# 103   Kennedy Nzechukwu       Paul Craig  Keith Peterson  2019-03-30
# 3607     Tom Blackledge   Anthony Perosh      John Sharp  2011-02-26
# 5029        Jack Nilson   Saeed Hosseini    Joe Hamilton  1997-05-30
# 5132      Frank Hamaker  Thaddeus Luster   John McCarthy  1994-03-11
#
#                                 location Winner  title_bout  \
# 103      Philadelphia, Pennsylvania, USA   Blue       False
# 3607  Sydney, New South Wales, Australia   Blue       False
# 5029               Augusta, Georgia, USA    Red       False
# 5132               Denver, Colorado, USA    Red       False
#
#            weight_class  no_of_rounds  B_current_lose_streak  ...  \
# 103   Light Heavyweight             3                    1.0  ...
# 3607  Light Heavyweight             3                    3.0  ...
# 5029        Lightweight             2                    0.0  ...
# ...

# %%
df.at[103,"R_Height_cms"] = 195.58
df.at[3607,"R_Height_cms"] = 182.88
df.at[5029,"R_Height_cms"] = 176.48
df.at[5132,"R_Height_cms"] = 187.96

# %%
df[df["B_Height_cms"].isnull()]
# Out:
#             R_fighter           B_fighter        Referee        date  \
# 3402       Terry Etim    Edward Faaloloto   Leon Roberts  2011-11-05
# 3518  Michael Johnson    Edward Faaloloto   Mark Matheny  2011-06-26
# 4978    Laverne Clark       Frank Caracci  Tony Mullinax  1999-01-08
# 4992    Chuck Liddell       Noe Hernandez   Joe Hamilton  1998-05-15
# 5020      Alex Hunter          Sam Fulton   Joe Hamilton  1997-07-27
# 5029      Jack Nilson      Saeed Hosseini   Joe Hamilton  1997-05-30
# 5116     Ken Shamrock  Felix Lee Mitchell  John McCarthy  1994-09-09
# 5134    Patrick Smith          Ray Wizard  John McCarthy  1994-03-11
#
#                                  location Winner  title_bout  weight_class  \
# 3402  Birmingham, England, United Kingdom    Red       False   Lightweight
# 3518        Pittsburgh, Pennsylvania, USA    Red       False   Lightweight
# 4978          New Orleans, Louisiana, USA    Red       False   Lightweight
# ...

# %%
df.at[3402,"B_Height_cms"] = 175.26
df.at[3518,"B_Height_cms"] = 175.26
df.at[4978,"B_Height_cms"] = 170.18 
df.at[4992,"B_Height_cms"] = 184.11
df.at[5020,"B_Height_cms"] = 187.96
df.at[5029,"B_Height_cms"] = 176.60
df.at[5116,"B_Height_cms"] = 180.00
df.at[5134,"B_Height_cms"] = 184.91

# %%
df[df["R_Weight_lbs"].isnull()]
# Out:
#               R_fighter        B_fighter         Referee        date  \
# 103   Kennedy Nzechukwu       Paul Craig  Keith Peterson  2019-03-30
# 5029        Jack Nilson   Saeed Hosseini    Joe Hamilton  1997-05-30
# 5132      Frank Hamaker  Thaddeus Luster   John McCarthy  1994-03-11
#
#                              location Winner  title_bout       weight_class  \
# 103   Philadelphia, Pennsylvania, USA   Blue       False  Light Heavyweight
# 5029            Augusta, Georgia, USA    Red       False        Lightweight
# 5132            Denver, Colorado, USA    Red       False        Open Weight
#
#       no_of_rounds  B_current_lose_streak  ...  R_win_by_KO/TKO  \
# 103              3                    1.0  ...              0.0
# 5029             2                    0.0  ...              0.0
# 5132             1                    0.0  ...              0.0
#
#       R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  \
# ...

# %%
df.at[103,"R_Weight_lbs"] = 205
df.at[5029,"R_Weight_lbs"] = 155.99
df.at[5132,"R_Weight_lbs"] = 224.52

# %%
df[df["B_Weight_lbs"].isnull()]
# Out:
#           R_fighter           B_fighter        Referee        date  \
# 4978  Laverne Clark       Frank Caracci  Tony Mullinax  1999-01-08
# 4992  Chuck Liddell       Noe Hernandez   Joe Hamilton  1998-05-15
# 5020    Alex Hunter          Sam Fulton   Joe Hamilton  1997-07-27
# 5029    Jack Nilson      Saeed Hosseini   Joe Hamilton  1997-05-30
# 5116   Ken Shamrock  Felix Lee Mitchell  John McCarthy  1994-09-09
# 5134  Patrick Smith          Ray Wizard  John McCarthy  1994-03-11
#
#                             location Winner  title_bout  weight_class  \
# 4978     New Orleans, Louisiana, USA    Red       False   Lightweight
# 4992            Mobile, Alabama, USA    Red       False  Middleweight
# 5020        Birmingham, Alabama, USA    Red       False   Heavyweight
# 5029           Augusta, Georgia, USA    Red       False   Lightweight
# 5116  Charlotte, North Carolina, USA    Red       False   Open Weight
# 5134           Denver, Colorado, USA    Red       False   Open Weight
#
# ...

# %%
df.at[4978,"B_Weight_lbs"] = 200
df.at[4992,"B_Weight_lbs"] = 184.72
df.at[5020,"B_Weight_lbs"] = 250
df.at[5029,"B_Weight_lbs"] = 265
df.at[5116,"B_Weight_lbs"] = 224.52
df.at[5134,"B_Weight_lbs"] = 224.52

# %%
df.to_csv("updated_data.csv",index=False)

# %%
#mean calc
#df[df["weight_class"]=="Open Weight"]["R_Weight_lbs"].mean()

# %%
#check vals
new = pd.read_csv("data/updated_data.csv")
new[new["R_Weight_lbs"].isnull()]
# Out:
# Empty DataFrame
# ...
