# %%
from winners_only import *
from log import *
from historical import *
import pandas as pd
import numpy as np
import math
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
import xgboost as xgb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/updated_data.csv")

# %%
X_train, y_train, test_2019 = historical_cleaning(df)

# %% [markdown]
# # TRAIN XG BOOST MODEL

# %%
XGBR = xgb.XGBClassifier(colsample_bytree=0.4,
                gamma=0,
                learning_rate=0.07,
                max_depth=3,
                min_child_weight=1.5,
                n_estimators=2000,
                reg_alpha=0.75,
                reg_lambda=0.45,
                subsample=0.6,
                seed=42)

XGBR.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.4, gamma=0, learning_rate=0.07, max_delta_step=0,
#        max_depth=3, min_child_weight=1.5, missing=None, n_estimators=2000,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0.75, reg_lambda=0.45, scale_pos_weight=1, seed=42,
#        silent=True, subsample=0.6)

# %% [markdown]
# # Predict 2019 Fights

# %%
#Prediction numbers on cleaned 2019 Fighter Data

prediction = pd.DataFrame(test_2019["Fighter"])


test_2019 = test_2019.drop(columns = ["Fighter","Result"])


prediction["Win Probability"] = XGBR.predict_proba(test_2019)[:,0]

prediction = prediction.set_index("Fighter")

p2019 = prediction.to_dict()["Win Probability"]

# %%
len(prediction)
# Out:
# 384

# %%
comparison = df[["R_fighter","B_fighter","Winner","date"]]
comparison["year"] = comparison["date"].apply(lambda x: x[:-6])
comparison = comparison[comparison["year"] == "2019"]
comparison = comparison.drop(columns = ["date","year"])

# %%
len(comparison)
# Out:
# 223

# %%
# Out:
# {'Henry Cejudo': 0.5968008637428284,
#  'Valentina Shevchenko': 0.42016321420669556,
#  'Tony Ferguson': 0.2784407138824463,
#  'Tatiana Suarez': 0.11302018165588379,
#  'Aljamain Sterling': 0.31665122509002686,
#  'Yan Xiaonan': 0.392566442489624,
#  'Eddie Wineland': 0.4293704032897949,
#  'Katlyn Chookagian': 0.5214021801948547,
#  'Makwan Amirkhani': 0.5023273229598999,
#  'Daniel Teymur': 0.8039445877075195,
#  'Joel Alvarez': 0.7200921773910522,
#  'Rafael Dos Anjos': 0.5295295715332031,
#  'Vicente Luque': 0.2695237398147583,
#  'Charles Oliveira': 0.3741474747657776,
#  'Davi Ramos': 0.3721686601638794,
#  'Aspen Ladd': 0.7601134777069092,
#  'Desmond Green': 0.4247284531593323,
#  'Zak Cummings': 0.6149184703826904,
#  'Julio Arce': 0.501708984375,
#  'Jared Cannonier': 0.3435858488082886,
#  'Irene Aldana': 0.49044275283813477,
#  'Thiago Moises': 0.22485482692718506,
#  'Warlley Alves': 0.4775661826133728,
#  'Raoni Barcelos': 0.7683205604553223,
#  'Derek Brunson': 0.796075701713562,
#  'Walt Harris': 0.5398122072219849,
#  'Macy Chiasson': 0.5070843696594238,
#  'Nordine Taleb': 0.7106415033340454,
#  'Arjan Bhullar': 0.37777745723724365,
#  'Greg Hardy': 0.3027533292770386,
#  'Glover Teixeira': 0.6464107036590576,
#  'Roosevelt Roberts': 0.5423102378845215,
#  'Carla Esparza': 0.62339186668396,
#  'Gilbert Burns': 0.5422588586807251,
#  'Jim Miller': 0.6233645081520081,
#  'Angela Hill': 0.7658470869064331,
#  'Alistair Overeem': 0.5983603000640869,
#  'Islam Makhachev': 0.5862327814102173,
#  'Sergei Pavlovich': 0.4404605031013489,
#  'Roxanne Modafferi': 0.931870698928833,
#  'Jonathan Martinez': 0.8851310014724731,
#  'Marlon Moraes': 0.7121068239212036,
#  'Said Nurmagomedov': 0.3197183609008789,
#  'Allen Crowder': 0.2819703221321106,
#  'Geoff Neal': 0.5467281341552734,
#  'Chance Rencountre': 0.6708898544311523,
#  'Jimmie Rivera': 0.3682277202606201,
#  'Tai Tuivasa': 0.5393850803375244,
#  'Karolina Kowalkiewicz': 0.6189994812011719,
#  'Ricardo Lamas': 0.6481994390487671,
#  'Bevon Lewis': 0.5900387167930603,
#  'Alexander Gustafsson': 0.6096814274787903,
#  'Jimi Manuwa': 0.7989768981933594,
#  'Tonya Evinger': 0.9650692343711853,
#  'Stevie Ray': 0.4455277919769287,
#  'Nick Hein': 0.5746378898620605,
#  'Darko Stosic': 0.5794976949691772,
#  'Antonio Carlos Junior': 0.20420312881469727,
#  'Megan Anderson': 0.5734172463417053,
#  'Danny Roberts': 0.4969288110733032,
#  'Michael Trizano': 0.42418450117111206,
#  'Patrick Cummins': 0.6904153823852539,
#  'Rose Namajunas': 0.11310160160064697,
#  'Rogerio Nogueira': 0.5119050741195679,
#  'BJ Penn': 0.8185595273971558,
#  'Talita Bernardo': 0.5698826909065247,
#  'Al Iaquinta': 0.7473359107971191,
#  'Cub Swanson': 0.5044658780097961,
#  'Brad Katona': 0.18356668949127197,
#  'Aiemann Zahabi': 0.4979378581047058,
#  'Kyle Nelson': 0.7668299674987793,
#  'Mitch Gagnon': 0.5583705902099609,
#  'Jacare Souza': 0.6219854354858398,
#  'Alex Oliveira': 0.34168511629104614,
#  'John Lineker': 0.27878791093826294,
#  'Ben Saunders': 0.5556800365447998,
#  'Andrei Arlovski': 0.7929834127426147,
#  'Court McGee': 0.4283355474472046,
#  'Marcin Tybura': 0.326946496963501,
#  'Gadzhimurad Antigulov': 0.43735241889953613,
#  'Max Holloway': 0.3024486303329468,
#  'Kelvin Gastelum': 0.5457080602645874,
#  'Eryk Anders': 0.4845621585845947,
#  'Alan Jouban': 0.6639478802680969,
#  'Ovince Saint Preux': 0.6895349621772766,
#  'Wilson Reis': 0.6728436946868896,
#  'Curtis Millender': 0.8371123671531677,
#  'Lauren Mueller': 0.6312031745910645,
#  'Edson Barboza': 0.6345540285110474,
#  'David Branch': 0.5535984635353088,
#  'Ross Pearson': 0.7738710045814514,
#  'Enrique Barzola': 0.08652311563491821,
#  'Ray Borg': 0.30035334825515747,
#  'Stephen Thompson': 0.6969985961914062,
#  'Alexis Davis': 0.7675668001174927,
#  'Eric Shelton': 0.5902717113494873,
#  'Darren Till': 0.351280152797699,
#  'Volkan Oezdemir': 0.6039867401123047,
#  'Danny Henry': 0.7824715375900269,
#  'Derrick Lewis': 0.4612000584602356,
#  'Tim Means': 0.4171637296676636,
#  'Tim Boetsch': 0.6814121007919312,
#  'Marion Reneau': 0.6863812804222107,
#  'Louis Smolka': 0.6172268390655518,
#  'Tyron Woodley': 0.24119865894317627,
#  'Robbie Lawler': 0.6560976505279541,
#  'Tecia Torres': 0.7642706036567688,
#  'Cody Garbrandt': 0.6519471406936646,
#  'Jeremy Stephens': 0.541573166847229,
#  'Misha Cirkunov': 0.38725173473358154,
#  'Gina Mazany': 0.5157676935195923,
#  'Polyana Viana': 0.305292546749115,
#  'Jan Blachowicz': 0.5400383472442627,
#  'Gian Villante': 0.5074790716171265,
#  'John Dodson': 0.6232403516769409,
#  'Veronica Macedo': 0.6441318988800049,
#  'Michel Prazeres': 0.2560029625892639,
#  'Rustam Khabilov': 0.17441946268081665,
#  'James Vick': 0.34076666831970215,
#  'Cortney Casey': 0.7513309717178345,
#  'Alex Caceres': 0.757372260093689,
#  'Benito Lopez': 0.1856377124786377,
#  'Ashlee Evans-Smith': 0.6220248937606812,
#  'Scott Holtzman': 0.5905982255935669,
#  'Renan Barao': 0.6865402460098267,
#  'Alexandra Albu': 0.5542064905166626,
#  'Rani Yahya': 0.4704807996749878,
#  'Teruto Ishihara': 0.3836122751235962,
#  'Wuliji Buren': 0.6385440826416016,
#  'Raphael Assuncao': 0.5196768641471863,
#  'Junior Albini': 0.8263354897499084,
#  'Ricardo Ramos': 0.5074331760406494,
#  'Magomed Bibulatov': 0.14969104528427124,
#  'Alexander Hernandez': 0.666458249092102,
#  'Jessica Eye': 0.4580215811729431,
#  'Nina Ansaroff': 0.42122942209243774,
#  'Kevin Lee': 0.16943371295928955,
#  'Sijara Eubanks': 0.7799831628799438,
#  'Trevin Giles': 0.18842756748199463,
#  'Julian Erosa': 0.5220788717269897,
#  'Anderson Silva': 0.5892455577850342,
#  'Bethe Correia': 0.6935084462165833,
#  'Kurt Holobaugh': 0.644413948059082,
#  'Sergio Moraes': 0.26566219329833984,
#  'Priscila Cachoeira': 0.5868868827819824,
#  'Elias Theodorou': 0.27698713541030884,
#  'Sarah Moras': 0.7462424039840698,
#  'Juan Adams': 0.19556522369384766,
#  'Dmitrii Smoliakov': 0.6722247004508972,
#  'Ion Cutelaba': 0.23556005954742432,
#  'Jason Gonzalez': 0.6332800388336182,
#  'Jodie Esquibel': 0.7022256255149841,
#  'Aleksei Oleinik': 0.7495675086975098,
#  'Marcelo Golm': 0.5637218356132507,
#  'Antonina Shevchenko': 0.8166463375091553,
#  'Keita Nakamura': 0.5900541543960571,
#  'Andre Soukhamthath': 0.5724511742591858,
#  'Michael Johnson': 0.5999569892883301,
#  'Sheymon Moraes': 0.36843937635421753,
#  'Jessica Aguilar': 0.8816943764686584,
#  'Gerald Meerschaert': 0.7175811529159546,
#  'Mark De La Rosa': 0.3318323493003845,
#  'Justin Willis': 0.10359513759613037,
#  'Jesus Pinedo': 0.4841017723083496,
#  'Deiveson Figueiredo': 0.5064008235931396,
#  'Steven Peterson': 0.688836932182312,
#  'JJ Aldrich': 0.17095166444778442,
#  'Bobby Moffett': 0.5506350994110107,
#  'Frankie Saenz': 0.5568498373031616,
#  'Gunnar Nelson': 0.6996574997901917,
#  'Jose Quinonez': 0.4041166305541992,
#  'John Phillips': 0.8664833307266235,
#  'Jordan Rinaldi': 0.35463041067123413,
#  'Joe Duffy': 0.5916656851768494,
#  'Nad Narimani': 0.5919233560562134,
#  'Ben Rothwell': 0.67719566822052,
#  'Drew Dober': 0.2529207468032837,
#  'Zak Ottow': 0.5846420526504517,
#  'Dan Moret': 0.9096357822418213,
#  'Alejandro Perez': 0.24304527044296265,
#  'Mickey Gall': 0.6304484605789185,
#  'Charles Byrd': 0.3311055898666382,
#  'Marcos Rogerio de Lima': 0.31089746952056885,
#  'Lucie Pudilova': 0.31096673011779785,
#  'Carlo Pedersoli': 0.4614173173904419,
#  'Polo Reyes': 0.7568776607513428,
#  'Cain Velasquez': 0.39474987983703613,
#  'Bryan Barberena': 0.5283929109573364,
#  'Myles Jury': 0.534056544303894,
#  'Nadia Kassem': 0.4626798629760742,
#  'Sam Alvey': 0.4753653407096863,
#  'Dong Hyun Ma': 0.6525284647941589,
#  'Austin Arnett': 0.3544614315032959,
#  'Renato Moicano': 0.23402786254882812,
#  'Lyman Good': 0.5181231498718262,
#  'David Teymur': 0.58524489402771,
#  'Justin Ledet': 0.5931041240692139,
#  'TJ Dillashaw': 0.4612603783607483,
#  'Yancy Medeiros': 0.5419464111328125,
#  'Dustin Ortiz': 0.4621674418449402,
#  'Rachael Ostovich': 0.5391249656677246,
#  'Karl Roberson': 0.27164244651794434,
#  'Te Edwards': 0.5167574286460876}

# %%
comparison["R_Fighter_Proba"] = comparison["R_fighter"].apply(lambda x: p2019[x] if x in list(p2019.keys()) else 0)

# %%
comparison["B_Fighter_Proba"] = comparison["B_fighter"].apply(lambda x: p2019[x] if x in list(p2019.keys()) else 0)

# %%
comparison.head()
# Out:
#               R_fighter       B_fighter Winner  R_Fighter_Proba  \
# 0          Henry Cejudo   Marlon Moraes    Red         0.596801
# 1  Valentina Shevchenko     Jessica Eye    Red         0.420163
# 2         Tony Ferguson  Donald Cerrone    Red         0.278441
# 3         Jimmie Rivera        Petr Yan   Blue         0.368228
# 4           Tai Tuivasa   Blagoy Ivanov   Blue         0.539385
#
#    B_Fighter_Proba
# 0         0.712107
# 1         0.458022
# 2         0.572151
# 3         0.387402
# 4         0.717909

# %%
comparison["Proba Results"] = comparison.apply(lambda x: "Red" if x["R_Fighter_Proba"] >= x["B_Fighter_Proba"] else "Blue",axis=1)

# %%
comparison["Correct"] = comparison["Winner"] == comparison["Proba Results"]

# %%
a = list(comparison["Correct"])

# %%
np.mean(a)
# Out:
# 0.49327354260089684

# %%
len(comparison)
# Out:
# 223

# %%
comparison.head()
# Out:
#               R_fighter       B_fighter Winner  R_Fighter_Proba  \
# 0          Henry Cejudo   Marlon Moraes    Red         0.596801
# 1  Valentina Shevchenko     Jessica Eye    Red         0.420163
# 2         Tony Ferguson  Donald Cerrone    Red         0.278441
# 3         Jimmie Rivera        Petr Yan   Blue         0.368228
# 4           Tai Tuivasa   Blagoy Ivanov   Blue         0.539385
#
#    B_Fighter_Proba Proba Results  Correct
# 0         0.712107          Blue    False
# 1         0.458022          Blue    False
# 2         0.572151          Blue    False
# 3         0.387402          Blue     True
# 4         0.717909          Blue     True

# %%
comparison["P_D"] = comparison["R_Fighter_Proba"] - comparison["B_Fighter_Proba"]

# %%
comparison.describe()
# Out:
#        R_Fighter_Proba  B_Fighter_Proba         P_D
# count       223.000000       223.000000  223.000000
# mean          0.481845         0.409018    0.072827
# std           0.222389         0.267779    0.346007
# min           0.000000         0.000000   -0.885562
# 25%           0.352295         0.200533   -0.175679
# 50%           0.507433         0.459442    0.042958
# 75%           0.640642         0.600331    0.306502
# max           0.965069         0.927298    0.832165
