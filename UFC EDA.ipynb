# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data/updated_again_data.csv')

# %%
df.head(10)
# Out:
#                R_fighter       B_fighter          Referee        date  \
# 0           Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1   Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019-06-08
# 2          Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 3          Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 4            Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
# 5         Tatiana Suarez   Nina Ansaroff  Robert Madrigal  2019-06-08
# 6      Aljamain Sterling    Pedro Munhoz     Marc Goddard  2019-06-08
# 7  Karolina Kowalkiewicz    Alexa Grasso  Kevin MacDonald  2019-06-08
# 8          Ricardo Lamas   Calvin Kattar  Dan Miragliotta  2019-06-08
# 9            Yan Xiaonan     Angela Hill  Robert Madrigal  2019-06-08
#
#                  location Winner  title_bout         weight_class  \
# 0  Chicago, Illinois, USA    Red        True         Bantamweight
# ...

# %%
fighters = df["R_fighter"]

# %%
f2 = df["B_fighter"]

# %%
combined = fighters.append(f2)

# %%
a = combined.value_counts()

# %%
len(a)
# Out:
# 1915

# %%
import seaborn as sb
sb.distplot(a)

# %%
a.median()
# Out:
# 3.0

# %%
df.head(10)
# Out:
#                R_fighter       B_fighter          Referee        date  \
# 0           Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1   Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019-06-08
# 2          Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 3          Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 4            Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
# 5         Tatiana Suarez   Nina Ansaroff  Robert Madrigal  2019-06-08
# 6      Aljamain Sterling    Pedro Munhoz     Marc Goddard  2019-06-08
# 7  Karolina Kowalkiewicz    Alexa Grasso  Kevin MacDonald  2019-06-08
# 8          Ricardo Lamas   Calvin Kattar  Dan Miragliotta  2019-06-08
# 9            Yan Xiaonan     Angela Hill  Robert Madrigal  2019-06-08
#
#                  location Winner  title_bout         weight_class  \
# 0  Chicago, Illinois, USA    Red        True         Bantamweight
# ...

# %%
df[df["R_fighter"]=="Chris Weidman"]
# Out:
#           R_fighter        B_fighter          Referee        date  \
# 323   Chris Weidman     Jacare Souza  Dan Miragliotta  2018-11-03
# 905   Chris Weidman  Kelvin Gastelum    John McCarthy  2017-07-22
# 1045  Chris Weidman   Gegard Mousasi  Dan Miragliotta  2017-04-08
# 1248  Chris Weidman      Yoel Romero   Mario Yamasaki  2016-11-12
# 1655  Chris Weidman    Luke Rockhold        Herb Dean  2015-12-12
# 1933  Chris Weidman    Vitor Belfort        Herb Dean  2015-05-23
# 2364  Chris Weidman    Lyoto Machida        Herb Dean  2014-07-05
# 2617  Chris Weidman   Anderson Silva        Herb Dean  2013-12-28
#
#                           location Winner  title_bout  weight_class  \
# 323   New York City, New York, USA   Blue       False  Middleweight
# 905       Uniondale, New York, USA    Red       False  Middleweight
# 1045        Buffalo, New York, USA   Blue       False  Middleweight
# 1248  New York City, New York, USA   Blue       False  Middleweight
# ...

# %%
#removing draws
df = df[df["Winner"] != "Draw"]

# %%
weight_classes_dict = {"1" : 'Flyweight', 
                  "2" : 'Bantamweight', 
                  "3" : 'Featherweight', 
                  "4" : 'Lightweight',
                  "5" : 'Welterweight', 
                  "6" : 'Middleweight', 
                  "7" : 'Light Heavyweight',
                  "8" : 'Heavyweight', 
                  "9" : "Women's Strawweight", 
                  "10" : "Women's Flyweight",
                  "11" : "Women's Bantamweight", 
                  "12" : "Women's Featherweight"}
                       
                       

to_drop = ['Open Weight','Catch Weight',
 "Women's Strawweight",
 "Women's Flyweight",
 "Women's Bantamweight",
 "Women's Featherweight"]

for each in to_drop:
    df = df[df["weight_class"]!=each]

# %%
df["B_age"] = df["B_age"].fillna(df["B_age"].mean())
df["R_age"] = df["R_age"].fillna(df["R_age"].mean())

# %%
list(weight_classes_dict.values())
# Out:
# ['Flyweight',
#  'Bantamweight',
#  'Featherweight',
#  'Lightweight',
#  'Welterweight',
#  'Middleweight',
#  'Light Heavyweight',
#  'Heavyweight',
#  "Women's Strawweight",
#  "Women's Flyweight",
#  "Women's Bantamweight",
#  "Women's Featherweight"]

# %%
list(df.columns)
# Out:
# ['R_fighter',
#  'B_fighter',
#  'Referee',
#  'date',
#  'location',
#  'Winner',
#  'title_bout',
#  'weight_class',
#  'no_of_rounds',
#  'B_current_lose_streak',
#  'B_current_win_streak',
#  'B_draw',
#  'B_avg_BODY_att',
#  'B_avg_BODY_landed',
#  'B_avg_CLINCH_att',
#  'B_avg_CLINCH_landed',
#  'B_avg_DISTANCE_att',
#  'B_avg_DISTANCE_landed',
#  'B_avg_GROUND_att',
#  'B_avg_GROUND_landed',
#  'B_avg_HEAD_att',
#  'B_avg_HEAD_landed',
#  'B_avg_KD',
#  'B_avg_LEG_att',
#  'B_avg_LEG_landed',
#  'B_avg_PASS',
#  'B_avg_REV',
#  'B_avg_SIG_STR_att',
#  'B_avg_SIG_STR_landed',
#  'B_avg_SIG_STR_pct',
#  'B_avg_SUB_ATT',
#  'B_avg_TD_att',
#  'B_avg_TD_landed',
#  'B_avg_TD_pct',
#  'B_avg_TOTAL_STR_att',
#  'B_avg_TOTAL_STR_landed',
#  'B_longest_win_streak',
#  'B_losses',
#  'B_avg_opp_BODY_att',
#  'B_avg_opp_BODY_landed',
#  'B_avg_opp_CLINCH_att',
#  'B_avg_opp_CLINCH_landed',
#  'B_avg_opp_DISTANCE_att',
#  'B_avg_opp_DISTANCE_landed',
#  'B_avg_opp_GROUND_att',
# ...

# %% [markdown]
# # Date Related EDA

# %%
df["year"] = df["date"].apply(lambda x: x[:-6])
df["month"] = df["date"].apply(lambda x: x[5:-3])

# %%
data = df["year"].value_counts()

# %%
X = data.keys()
y = data

# %%
# X = X.drop('2019')

# %%
# y = y.drop('2019')

# %%
plt.figure(figsize=(16, 6))
sns.lineplot(X,y)
plt.title("UFC Fights Per Year 1993-2018",fontsize='24')
plt.xlabel("Year", fontsize = '24')
plt.ylabel("Number of Fights", fontsize = '24')
# Out:
# Text(0, 0.5, 'Number of Fights')

# %%
df.groupby(["year","month"])["year"].count()
# Out:
# year  month
# 1997  02        7
#       05        9
#       07        9
#       10        7
#       12        6
# 1998  03        6
#       05        8
#       10        6
# 1999  01        7
#       03        7
#       05        7
#       07        7
#       09        6
#       11        5
# 2000  03        7
#       04        6
#       06        6
#       09        7
#       11        7
#       12        7
# 2001  02        7
#       05        8
#       06        8
#       09        8
#       11        8
# 2002  01        8
#       03        8
#       05        7
#       06        6
#       07        7
#                ..
# 2017  01       22
#       02       25
#       03       29
#       04       33
#       05       21
#       06       37
#       07       50
#       08       11
#       09       37
#       10       28
#       11       41
#       12       43
# 2018  01       27
#       02       41
#       03       19
#       04       29
#       05       30
#       06       32
# ...

# %% [markdown]
# # Weight Class EDA

# %%
df.groupby("weight_class")["weight_class"].count()
# Out:
# weight_class
# Bantamweight         371
# Featherweight        434
# Flyweight            185
# Heavyweight          497
# Light Heavyweight    492
# Lightweight          971
# Middleweight         717
# Welterweight         956
# Name: weight_class, dtype: int64

# %%
df.groupby("R_fighter")["R_fighter"]

# %% [markdown]
# # One Way Only

# %%
df[df["R_fighter"] == "Aaron Phillips"]
# Out:
#            R_fighter   B_fighter    Referee        date              location  \
# 2297  Aaron Phillips  Matt Hobar  Kevin Nix  2014-08-23  Tulsa, Oklahoma, USA
#
#      Winner  title_bout  weight_class  no_of_rounds  B_current_lose_streak  \
# 2297   Blue       False  Bantamweight             3                    1.0
#
#       B_current_win_streak  B_draw  B_avg_BODY_att  B_avg_BODY_landed  \
# 2297                   0.0     0.0             2.0                1.0
#
#       B_avg_CLINCH_att  B_avg_CLINCH_landed  B_avg_DISTANCE_att  \
# 2297               2.0                  2.0                25.0
#
#       B_avg_DISTANCE_landed  B_avg_GROUND_att  B_avg_GROUND_landed  \
# 2297                    5.0               0.0                  0.0
#
#       B_avg_HEAD_att  B_avg_HEAD_landed  B_avg_KD  B_avg_LEG_att  \
# 2297            21.0                2.0       0.0            4.0
#
#       B_avg_LEG_landed  B_avg_PASS  B_avg_REV  B_avg_SIG_STR_att  \
# ...

# %%
df[df["R_fighter"] == "Matt Hobar"]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# # Winner Stats vs Loser Stats

# %%
blue_cols = [
 'Winner',
 'weight_class',
 'B_age',
 'B_Height_cms',
 'B_Reach_cms_Updates',
 'B_Weight_lbs']
red_cols = [
 'Winner',
 'weight_class',
 'R_age',
 'R_Height_cms',
 'R_Reach_cms_Updates',
 'R_Weight_lbs']


reduced_red = df[red_cols]
reduced_blue = df[blue_cols]
print(len(reduced_red))
print(len(reduced_blue))
# Out:
# 4623
# 4623

# %%
red_win = reduced_red[reduced_red["Winner"] == "Red"]
red_lose = reduced_red[reduced_red["Winner"] != "Red"]
blue_win = reduced_blue[reduced_red["Winner"] == "Blue"]
blue_lose = reduced_blue[reduced_red["Winner"] != "Blue"]

print(len(red_win))
print(len(red_lose))
print(len(blue_win))
print(len(blue_lose))
# Out:
# 3165
# 1458
# 1458
# 3165

# %%
headers = ["Winner","Weight Class","Age","Height","Reach","Weight"]

red_win.columns = headers
blue_win.columns = headers
red_lose.columns = headers
blue_lose.columns = headers

red_lose.head()
# Out:
#    Winner       Weight Class   Age  Height   Reach  Weight
# 3    Blue       Bantamweight  29.0  162.56  172.72   135.0
# 4    Blue        Heavyweight  26.0  187.96  190.50   264.0
# 8    Blue      Featherweight  37.0  172.72  180.34   145.0
# 10   Blue       Middleweight  28.0  190.50  200.66   185.0
# 13   Blue  Light Heavyweight  32.0  195.58  200.66   205.0

# %%
winners = red_win.append(blue_win)
losers = red_lose.append(blue_lose)

# %%
#Reach Diff
winners.groupby("Weight Class")["Reach"].mean() - losers.groupby("Weight Class")["Reach"].mean()
# Out:
# Weight Class
# Bantamweight        -0.613890
# Featherweight        0.425284
# Flyweight           -0.393586
# Heavyweight          1.214634
# Light Heavyweight    1.574593
# Lightweight          0.168287
# Middleweight         0.621125
# Welterweight         0.549979
# Name: Reach, dtype: float64

# %% [markdown]
# # REACH DIFFERENCES PER WEIGHT CLASS

# %%
import seaborn as sb

# %%
axes[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-a062ca222676> in <module>
# ----> 1 axes[0]
#
# NameError: name 'axes' is not defined

# %%
wc = list(weight_classes_dict.values())
num = len(wc)
fig, axes = plt.subplots(num,1, figsize=(8,64))
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)



for i,each in enumerate(wc):
    sb.distplot(winners[winners["Weight Class"]==each]["Reach"],color="r",bins=10,ax=axes[i])
    sb.distplot(losers[losers["Weight Class"]==each]["Reach"],color='b',bins=10,ax=axes[i])
#     ax[i].axvline(winners[winners["Weight Class"]==each]["Reach"].mean(),color="r")
#     ax[i].axvline(losers[losers["Weight Class"]==each]["Reach"].mean(),color="b")
    axes[i].set_title(each+" Reach Differences",fontsize="24")
    axes[i].set_xlabel("Reach (Centimeters)",fontsize="16")
    axes[i].legend(['Winners','Losers'])
    axes[i].axvline(winners[winners["Weight Class"]==each]["Reach"].mean(),color='r')
    axes[i].axvline(losers[losers["Weight Class"]==each]["Reach"].mean(),color='b')
# sb.distplot(winners[winners["Weight Class"]==each]["Reach"],color="r")
# sb.distplot(losers[losers["Weight Class"]==each]["Reach"],color="b")
# sb.distplot(winners[winners["Weight Class"]==each]["Reach"],color="r",ax=axes[0,0])
# sb.distplot(losers[losers["Weight Class"]==each]["Reach"],color="b",ax=axes[0,0])
# sb.distplot(winners[winners["Weight Class"]==each]["Reach"],color="r",ax=axes[1,0])
# sb.distplot(losers[losers["Weight Class"]==each]["Reach"],color="b",ax=axes[0,1])

# %%
wc = list(weight_classes_dict.values())
num = len(wc)
fig, ax = plt.subplots(num,1, figsize=(16,48))

for i,each in enumerate(wc):
    ax[i].hist(winners[winners["Weight Class"]==each]["Reach"],color="r",alpha=0.25)
    ax[i].hist(losers[losers["Weight Class"]==each]["Reach"],color='b',alpha=0.25)
    ax[i].axvline(winners[winners["Weight Class"]==each]["Reach"].mean(),color="r")
    ax[i].axvline(losers[losers["Weight Class"]==each]["Reach"].mean(),color="b")
    ax[i].set_title(each)

# %% [markdown]
# # HEIGHT DIFFERENCES PER WEIGHT CLASS

# %%
#Height Diff
winners.groupby("Weight Class")["Height"].mean() - losers.groupby("Weight Class")["Height"].mean()
# Out:
# Weight Class
# Bantamweight        -0.335472
# Featherweight       -0.158018
# Flyweight           -1.180757
# Heavyweight          0.434406
# Light Heavyweight    0.877642
# Lightweight          0.075736
# Middleweight         0.540293
# Welterweight         0.300230
# Name: Height, dtype: float64

# %%
wc = list(weight_classes_dict.values())
num = len(wc)
fig, ax = plt.subplots(num,1, figsize=(16,48))

thing = "Height"

for i,each in enumerate(wc):
    ax[i].hist(winners[winners["Weight Class"]==each][thing],color="r",alpha=0.25)
    ax[i].hist(losers[losers["Weight Class"]==each][thing],color='b',alpha=0.25)
    ax[i].axvline(winners[winners["Weight Class"]==each][thing].mean(),color="r")
    ax[i].axvline(losers[losers["Weight Class"]==each][thing].mean(),color="b")
    ax[i].set_title(each)

# %%
wc = list(weight_classes_dict.values())
num = len(wc)
fig, axes = plt.subplots(num,1, figsize=(8,64))
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

thing = "Height"

for i,each in enumerate(wc):
    sb.distplot(winners[winners["Weight Class"]==each][thing],color="r",bins=10,ax=axes[i])
    sb.distplot(losers[losers["Weight Class"]==each][thing],color='b',bins=10,ax=axes[i])
    axes[i].set_title(each+" Height Differences",fontsize="24")
    axes[i].set_xlabel("Height (Centimeters)",fontsize="16")
    axes[i].legend(['Winners','Losers'])
    axes[i].axvline(winners[winners["Weight Class"]==each][thing].mean(),color='r')
    axes[i].axvline(losers[losers["Weight Class"]==each][thing].mean(),color='b')

# %% [markdown]
# # Weight DIFFERENCES PER WEIGHT CLASS

# %%
#Weight Diff
winners.groupby("Weight Class")["Weight"].mean() - losers.groupby("Weight Class")["Weight"].mean()
# Out:
# Weight Class
# Bantamweight        -0.242588
# Featherweight        0.472350
# Flyweight            0.594595
# Heavyweight          0.275654
# Light Heavyweight    0.506098
# Lightweight          0.490206
# Middleweight         0.093835
# Welterweight         0.738494
# Name: Weight, dtype: float64

# %%
wc = list(weight_classes_dict.values())
num = len(wc)
fig, ax = plt.subplots(num,1, figsize=(16,48))

thing = "Weight"

for i,each in enumerate(wc):
    ax[i].hist(winners[winners["Weight Class"]==each][thing],color="r",alpha=0.25)
    ax[i].hist(losers[losers["Weight Class"]==each][thing],color='b',alpha=0.25)
    ax[i].axvline(winners[winners["Weight Class"]==each][thing].mean(),color="r")
    ax[i].axvline(losers[losers["Weight Class"]==each][thing].mean(),color="b")
    ax[i].set_title(each)

# %%
wc = list(weight_classes_dict.values())
num = len(wc)
fig, axes = plt.subplots(num,1, figsize=(8,64))
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

thing = "Weight"

for i,each in enumerate(wc):
    sb.distplot(winners[winners["Weight Class"]==each][thing],color="r",bins=10,ax=axes[i])
    sb.distplot(losers[losers["Weight Class"]==each][thing],color='b',bins=10,ax=axes[i])
    axes[i].set_title(each+" Height Differences",fontsize="24")
    axes[i].set_xlabel("Height (Centimeters)",fontsize="16")
    axes[i].legend(['Winners','Losers'])
    axes[i].axvline(winners[winners["Weight Class"]==each][thing].mean(),color='r')
    axes[i].axvline(losers[losers["Weight Class"]==each][thing].mean(),color='b')

# %% [markdown]
# # AGE DIFFERENCES PER WEIGHT CLASS

# %%
#Age Diff
winners.groupby("Weight Class")["Age"].mean() - losers.groupby("Weight Class")["Age"].mean()
# Out:
# Weight Class
# Bantamweight        -0.932615
# Featherweight       -1.043779
# Flyweight           -0.859459
# Heavyweight         -0.939519
# Light Heavyweight   -1.003455
# Lightweight         -0.874697
# Middleweight        -0.386498
# Welterweight        -0.449102
# Name: Age, dtype: float64

# %%
wc = list(weight_classes_dict.values())
num = len(wc)
fig, ax = plt.subplots(num,1, figsize=(16,48))

thing = "Age"

for i,each in enumerate(wc):
    ax[i].hist(winners[winners["Weight Class"]==each][thing],color="r",alpha=0.25)
    ax[i].hist(losers[losers["Weight Class"]==each][thing],color='b',alpha=0.25)
    ax[i].axvline(winners[winners["Weight Class"]==each][thing].mean(),color="r")
    ax[i].axvline(losers[losers["Weight Class"]==each][thing].mean(),color="b")
    ax[i].set_title(each)

# %%
wc = list(weight_classes_dict.values())
num = len(wc)
fig, axes = plt.subplots(num,1, figsize=(8,64))
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

thing = "Age"

for i,each in enumerate(wc):
    sb.distplot(winners[winners["Weight Class"]==each][thing],color="r",bins=10,ax=axes[i])
    sb.distplot(losers[losers["Weight Class"]==each][thing],color='b',bins=10,ax=axes[i])
    axes[i].set_title(each+" Age Differences",fontsize="24")
    axes[i].set_xlabel("Height (Centimeters)",fontsize="16")
    axes[i].legend(['Winners','Losers'])
    axes[i].axvline(winners[winners["Weight Class"]==each][thing].mean(),color='r')
    axes[i].axvline(losers[losers["Weight Class"]==each][thing].mean(),color='b')

# %%
losers[losers["Weight"]>300]
# Out:
#      Winner Weight Class        Age  Height       Reach  Weight
# 4964    Red  Heavyweight  29.182983  182.88  189.653333   335.0
# 4966    Red  Heavyweight  34.000000  187.96  193.886667   345.0
# 5014    Red  Heavyweight  27.000000  187.96  193.886667   345.0
# 5032    Red  Heavyweight  31.000000  180.34  188.806667   323.0

# %%
list(winners["Weight Class"].unique())
# Out:
# ['Bantamweight',
#  'Lightweight',
#  'Featherweight',
#  'Welterweight',
#  'Middleweight',
#  'Heavyweight',
#  'Light Heavyweight',
#  'Flyweight']

# %% [markdown]
# # WIN COUNTS

# %%
df["Winner"].value_counts()/df["Winner"].count()
# Out:
# Red     0.68462
# Blue    0.31538
# Name: Winner, dtype: float64

# %% [markdown]
# # How many Rounds?

# %%
df.groupby("no_of_rounds")["no_of_rounds"].count()
# Out:
# no_of_rounds
# 1       4
# 2      67
# 3    4154
# 4      19
# 5     379
# Name: no_of_rounds, dtype: int64

# %%
df[df["no_of_rounds"]==1]
# Out:
#           R_fighter        B_fighter       Referee        date  \
# 4992  Chuck Liddell    Noe Hernandez  Joe Hamilton  1998-05-15
# 5005  Tra Telligman      Brad Kohler  Joe Hamilton  1997-12-21
# 5011   Dwayne Cason     Houston Dorr  Joe Hamilton  1997-10-17
# 5012    Alex Hunter  Harry Moskowitz  Joe Hamilton  1997-10-17
#
#                              location Winner  title_bout  weight_class  \
# 4992             Mobile, Alabama, USA    Red       False  Middleweight
# 5005        Yokohama, Kanagawa, Japan    Red       False   Heavyweight
# 5011  Bay St. Louis, Mississippi, USA    Red       False   Heavyweight
# 5012  Bay St. Louis, Mississippi, USA    Red       False   Heavyweight
#
#       no_of_rounds  B_current_lose_streak  B_current_win_streak  B_draw  \
# 4992             1                    0.0                   0.0     0.0
# 5005             1                    0.0                   0.0     0.0
# 5011             1                    0.0                   0.0     0.0
# ...

# %% [markdown]
# # Advanced Stats EDA

# %%
df.head()
# Out:
#            R_fighter       B_fighter          Referee        date  \
# 0       Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 2      Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 3      Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 4        Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
# 6  Aljamain Sterling    Pedro Munhoz     Marc Goddard  2019-06-08
#
#                  location Winner  title_bout  weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True  Bantamweight             5
# 2  Chicago, Illinois, USA    Red       False   Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False  Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False   Heavyweight             3
# 6  Chicago, Illinois, USA    Red       False  Bantamweight             3
#
#    B_current_lose_streak  B_current_win_streak  B_draw  B_avg_BODY_att  \
# ...

# %%
df["R_avg_TOTAL_STR_att"].describe()
# Out:
# count    4067.000000
# mean       92.389915
# std        44.825830
# min         0.000000
# 25%        61.535714
# 50%        88.666667
# 75%       118.944444
# max       289.666667
# Name: R_avg_TOTAL_STR_att, dtype: float64

# %%
df["R_avg_TOTAL_STR_landed"].describe()
# Out:
# count    4067.000000
# mean       50.780389
# std        25.856507
# min         0.000000
# 25%        33.460606
# 50%        48.000000
# 75%        64.000000
# max       202.500000
# Name: R_avg_TOTAL_STR_landed, dtype: float64

# %%
df["R_Offensive_Accuracy"]

# %%
df2 = pd.read_csv("data/data2.csv")

# %%
df2.head()
# Out:
#    BPrev  BStreak  B_Age  B_Height                       B_HomeTown  B_ID  \
# 0      0        0   38.0     193.0                 Hounslow England   808
# 1      0        0   36.0     172.0  Chicago, Illinois United States  1054
# 2      0        0   39.0     167.0      Isla Vista , California USA   959
# 3      0        0   33.0     167.0                San Diego, CA USA  1056
# 4      0        0   36.0     185.0              Southampton England  2005
#
#                         B_Location            B_Name  B_Weight  \
# 0        Amsterdam The Netherlands  Alistair Overeem     120.0
# 1  Chicago, Illinois United States     Ricardo Lamas      65.0
# 2       Sacramento, California USA      Urijah Faber      61.0
# 3                San Diego, CA USA    Danny Martinez      56.0
# 4              Southampton England        Tom Watson      84.0
#
#    B__Round1_Grappling_Reversals_Landed  B__Round1_Grappling_Standups_Landed  \
# ...

# %%
df2.shape
# Out:
# (2318, 894)

# %%
df2["B__Round1_Grappling_Reversals_Landed"].describe()
# Out:
# count    1647.000000
# mean        0.074681
# std         0.305691
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         3.000000
# Name: B__Round1_Grappling_Reversals_Landed, dtype: float64

# %%
df[df["R_fighter"] == "Yushin Okami"]
# Out:
#          R_fighter          B_fighter           Referee        date  \
# 267   Yushin Okami  Aleksei Kunchenko      Neil Swailes  2018-12-01
# 2745  Yushin Okami       Jacare Souza      Leon Roberts  2013-09-04
# 2938  Yushin Okami     Hector Lombard         Herb Dean  2013-03-02
# 3006  Yushin Okami       Alan Belcher     Chris Tognoni  2012-12-29
# 3116  Yushin Okami      Buddy Roberts         Herb Dean  2012-08-11
# 3286  Yushin Okami        Tim Boetsch      Leon Roberts  2012-02-25
# 3832  Yushin Okami     Lucio Linhares         Dale Frye  2010-03-31
# 4117  Yushin Okami        Dean Lister         Herb Dean  2008-12-27
# 4279  Yushin Okami        Evan Tanner      Mark Matheny  2008-03-01
# 4346  Yushin Okami    Jason MacDonald      Mark Matheny  2007-10-20
# 4443  Yushin Okami         Mike Swick    Mario Yamasaki  2007-04-07
# 4491  Yushin Okami        Rory Singer  Steve Mazzagatti  2006-12-30
# 4524  Yushin Okami      Kalib Starnes      Yves Lavigne  2006-10-14
# ...

# %%
df["R_fighter"].value_counts()
# Out:
# Donald Cerrone              22
# Diego Sanchez               21
# Demian Maia                 21
# Michael Bisping             21
# Jim Miller                  21
# Joe Lauzon                  19
# Georges St-Pierre           19
# Anderson Silva              19
# Lyoto Machida               19
# Matt Hughes                 19
# Frank Mir                   19
# Thiago Alves                18
# Ross Pearson                18
# Frankie Edgar               18
# Andrei Arlovski             18
# Tito Ortiz                  17
# Chuck Liddell               17
# Josh Koscheck               17
# Clay Guida                  17
# BJ Penn                     17
# Jon Jones                   16
# Vitor Belfort               16
# Gray Maynard                16
# Dustin Poirier              16
# Randy Couture               16
# Rashad Evans                16
# Chris Leben                 16
# Gleison Tibau               16
# Mauricio Rua                16
# Joseph Benavidez            16
# ...
